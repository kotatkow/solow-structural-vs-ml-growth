# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

import numpy as np
import matplotlib.pyplot as plt
from src.simulation.solow import solow_simulation, steady_state

k_path = solow_simulation()
k_star = steady_state()

plt.plot(k_path)
plt.axhline(k_star, linestyle='--')
plt.title("Convergence to Steady State")
plt.show()
